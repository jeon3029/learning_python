# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('data/body.csv',index_col=0)
df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
df.plot(kind='hist',y='Height')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='hist',y='Height',bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='hist',y='Height',bins=200)#너무 세분화 하면 보기 힘듦
# Out:
# <AxesSubplot:ylabel='Frequency'>
