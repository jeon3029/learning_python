# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/body.csv',index_col=0)
df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
df['Height']
# Out:
# Number
# 1       176.0
# 2       175.3
# 3       168.6
# 4       168.1
# 5       175.3
#         ...
# 996     171.8
# 997     171.5
# 998     177.9
# 999     174.4
# 1000    173.5
# Name: Height, Length: 1000, dtype: float64

# %%
df['Height'].value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['Height'],bw=0.1) # 표준화 정도 조정
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
df.plot(kind='hist',y='Height',bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot(df['Height'],bins=15)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
df.plot(kind='box',y='Height')
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(y=df['Height'])
# Out:
# <AxesSubplot:ylabel='Height'>

# %%
df.plot(kind='scatter',x='Height',y='Weight')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(df['Height'],df['Weight']) #등고선
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(df['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>
